# %% [markdown]
# # Tarea - Caminata aleatoria y simulación montecarlo

# %% [markdown]
# #### 1. Simulación del movimiento browniano
#
# El movimiento browniano es el movimiento aleatorio que se observa en las partículas que se hallan en un medio fluido, como resultado de choques contra las moléculas de dicho fluido [(referencia)].
#
# [(referencia)]: https://es.wikipedia.org/wiki/Movimiento_browniano
#
# Para simular el movimiento, en lugar de usar las ecuaciones integro-diferenciales que describe Einstein, use una caminta aleatoria para los tres ejes $x$, $y$, $z$ de la siguiente forma
# $$
# W_i=W_{i-1}+X_i\sqrt{\Delta t}
# $$
# donde, $\Delta t$ es un intervalo de tiempo y
# $$
# X_i=\left\{\begin{array}{l}
# 1\\
# -1
# \end{array}\right.,
# $$
# se escoge de forma aleatoria con la misma probabilidad.
#
# Simule $10$ segundos con un $\Delta t=0.001$ y represéntelo en un gráfico 3D (Puede ver el archivo de Ejemplo 3D).

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
dt = 0.001
T = 10
N = int(T/dt)


x = np.zeros(N)
y = np.zeros(N)
z = np.zeros(N)


for i in range(1, N):
    xi = np.random.choice([-1, 1], size=3)
    x[i] = x[i-1] + xi[0]*np.sqrt(dt)
    y[i] = y[i-1] + xi[1]*np.sqrt(dt)
    z[i] = z[i-1] + xi[2]*np.sqrt(dt)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %% [markdown]
# #### 2. Apuesta arriesgada
#
# Un jugador, con 20 pesos de capital inicial, decide apostar a un volado (con una moneda perfectamente nivelada) la mitad de su capital si éste es mayor o igual a 6 pesos, de lo contrario, solo 2. Esto es, el capital $C_i$ en cada volado $V_i$ se describe como
# $$
# C_{i+1}=C_i+V_iA_i
# $$
# donde la apuesta es
# $$
# A_i=\left\{\begin{array}{l}
# C_i/2,\quad \mbox{si }C_i\geq 6\\
# 2,\quad \mbox{de lo contrario.}
# \end{array}\right.
# $$
#
# 1. Grafique la evolución del capital hasta quedar en cero.
# 2. Determine el número de volados promedio para quedar en quiebra usando la simulación montecarlo para 10,000 apostadores.
# 3. Muestre un histograma del número de volados.

# %%
import random

def apuesta(c):
    if c >= 6:
        return c/2
    else:
        return 2

def volado():
    opciones = [1,-1]
    return random.choice(opciones)

def partida():
    c = [20]
    while c[-1] > 0:
        c.append(c[-1] + (volado() * apuesta(c[-1])))
    return c

# %%
plt.figure()
r=partida()
plt.plot(r)

# %%
import numpy as np

def volado():
    return np.random.choice([-1, 1])

def apuesta(cantidad):
    return 0.5

def partida0():
    c = [20]
    n_volados = []
    while c[-1] > 0:
        c.append(c[-1] + (volado() * apuesta(c[-1])))
        n_volados.append(1)
    return len(c) - 1

n_volados = []
for _ in range(10):
    volados = partida0()
    n_volados.append(volados)

media = np.mean(n_volados)
print(media)
# Out:
# 13583.0

# %%
plt.hist(n_volados, bins=range(min(n_volados), max(n_volados) + 1), density=True, alpha=0.75, edgecolor='black')
plt.xlabel('Número de Volados')
plt.ylabel('Frecuencia Relativa')
plt.title('Distribución del Número de Volados en 10,000 Partidas')
plt.axvline(media, color='red', linestyle='dashed', linewidth=2, label=f'Media = {media:.2f}')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
