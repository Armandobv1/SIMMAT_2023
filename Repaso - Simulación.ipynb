# %% [markdown]
# # Repaso - Módulo 2
# ---

# %% [markdown]
# Jose Armando Borregui V
# 1919/19/2023

# %% [markdown]
# ## Cifrado
#
# Se recibió un mensaje cifrado con un método congruencial simple: $ x_n = (ax_{n-1}+b)\mod m $.
#
# El cifrado que se usó es el siguiente:
# - 0 corresponde a 'A'
# - 1 corresponde a 'B'
# - 2 corresponde a 'C'
# - ...
# - 25 corresponde a 'Z' (no hay 'Ñ')
# - Se toma la letra y se le suma un número aleatorio desconocido.
# - Se generan 3 números antes de empezar el cifrado; esto quiere decir que la primera letra es "Letra + $x_3$"
# - El mensaje que llegó fue: "12, 19, 15, 24"
#
# Sabiendo de antemano que los parámetros de este generador son $m=16$, $a=5$, $b=3$ y que la semilla fue $7$; ¿cuál es el mensaje decodificado?

# %%
m= 16
a= 5
b=3
semilla= 7 
mensaje=[12,19,15,24]
def decodificacion :
    xn=(ax+b)
    return

# %% [markdown]
# ## Evaluación numérica de integrales utilizando Montecarlo
# Escriba la función para integrar por el método Montecarlo de tipo 1

# %%
def montecarlo (f,n,a,b):
  u=np.random.uniform(a,b,n)
  media=np.mean(f(u))
  return media*(b-a)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# Graficamos
x1 = np.linspace(, 5, 100)
y1 = np.sqrt(1+x1**4)
plt.figure()
plt.plot(x1, y1, "k", label="$funcion 1$")
plt.text(0.4, 1.5, "$\mathcal{D}$", fontsize=20)
plt.fill_between(x1, y1)
plt.legend(loc="best")
plt.grid()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# Graficamos
x2= np.linspace(4, 5, 100)
y2 = np.log(np.log(x2))
plt.figure()
plt.plot(x1, y1, "k", label="$funcion 2$")

plt.fill_between(x2, y2)
plt.legend(loc="best")
plt.grid()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# Graficamos
x3 = np.linspace(4, 5, 100)
y3 = 1/np.log(x3)
plt.figure()
plt.plot(x3, y3, "k", label="$1/log x$")
plt.fill_between(x3, y3)
plt.legend(loc="best")
plt.grid()

# %% [markdown]
# Considere las funciones $f_1(x)=\sqrt{1+x^{4}}$, $f_2(x)=\ln(\ln x)$, $f_3(x)=\frac {1}{\ln x}$, y $f_4(x)=e^{-{\frac {x^{2}}{2}}}$.
#
# Utilizar la función anterior para realizar la evaluación numérica de las integrales de las funciones anteriores en el intervalo $(4,5)$. Poner los resultados en una tabla cuyas filas correspondan a la cantidad de términos utilizados en la aproximación (usar 10, 100, 1000, 10000 y 100000 términos) y cuyas columnas correspondan a las funciones.

# %%
import numpy as np
import random
import matplotlib.pyplot as plt


def f(x1):
  return np.sqrt(1+x1**4)
a=0
b=1
n=100
np.random.seed(14)
u1=np.random.uniform(a,b,n)
u1
np.mean(f(x1))
# Out:
# 1.0906180910590064

# %%
import pandas as pd
n=np.logspace(1,5,5)
n
table = pd.DataFrame(columns=["aproximacion","error"],index=n)
table
# Out:
#          aproximacion error
# 10.0              NaN   NaN
# 100.0             NaN   NaN
# 1000.0            NaN   NaN
# 10000.0           NaN   NaN
# 100000.0          NaN   NaN

# %%
def montecarlo (f,n,a,b):
  u=np.random.uniform(a,b,n)
  media=np.mean(f(u))
  return media*(b-a)

# %%
for i in n :
  aproximacion = montecarlo(f,int(i),4,5)
  table.loc[i,"aproximacion"]=aproximacion
  table.loc[i,"error"]=abs(1.0906180910590064-aproximacion)
table
# Out:
#          aproximacion     error
# 10.0         0.679476  0.411142
# 100.0        0.669914  0.420704
# 1000.0       0.667878   0.42274
# 10000.0      0.666684  0.423934
# 100000.0     0.667045  0.423574

# %% [markdown]
# ##2

# %%
import numpy as np
import random
import matplotlib.pyplot as plt


def f(x2):
  return np.log(np.log(x2))
a=0
b=1
n=100
np.random.seed(14)
u1=np.random.uniform(a,b,n)
u1
np.mean(f(x2))
# Out:
# 0.40583799881977883

# %%
import pandas as pd
n=np.logspace(1,5,5)
n
table = pd.DataFrame(columns=["aproximacion","error"],index=n)
table
# Out:
#          aproximacion error
# 10.0              NaN   NaN
# 100.0             NaN   NaN
# 1000.0            NaN   NaN
# 10000.0           NaN   NaN
# 100000.0          NaN   NaN

# %%
for i in n :
  aproximacion = montecarlo(f,int(i),4,5)
  table.loc[i,"aproximacion"]=aproximacion
  table.loc[i,"error"]=abs(np.mean(f(x2))-aproximacion)
table
# Out:
#          aproximacion     error
# 10.0         0.679476  0.012429
# 100.0        0.669914  0.002867
# 1000.0       0.667878  0.000831
# 10000.0      0.666684  0.000363
# 100000.0     0.667045  0.000002

# %% [markdown]
# ##3

# %%
import numpy as np
import random
import matplotlib.pyplot as plt


def f(x3):
  return 1/np.log(x3)
a=0
b=1
n=100
np.random.seed(14)
u1=np.random.uniform(a,b,n)
u1
np.mean(f(x3))
# Out:
# 0.6670470401864692

# %%
import pandas as pd
n=np.logspace(1,5,5)
n
table = pd.DataFrame(columns=["aproximacion","error"],index=n)
table
# Out:
#          aproximacion error
# 10.0              NaN   NaN
# 100.0             NaN   NaN
# 1000.0            NaN   NaN
# 10000.0           NaN   NaN
# 100000.0          NaN   NaN

# %%
for i in n :
  aproximacion = montecarlo(f,int(i),0,1)
  table.loc[i,"aproximacion"]=aproximacion
  table.loc[i,"error"]=abs(0.40583799881977883-aproximacion)
table
# Out:
#          aproximacion      error
# 10.0        -1.366718   1.772556
# 100.0       -5.555426   5.961264
# 1000.0     -17.859089  18.264927
# 10000.0    -16.869204  17.275042
# 100000.0   -12.707003  13.112841

# %% [markdown]
# ## Montecarlo Tipo 2
# Aproximar el área de la región descrita por
#
# $$x^2+2y^2\leq-2x+8y-7$$
#
# Poner los resultados en una tabla cuyas filas correspondan a la cantidad de términos utilizados en la aproximación (usar 10, 100, 1000, 10000 y 100000 términos) y en las columnas el valor de aproximación y el error de integración.
#
# Definir unos límites adecuados $a_1$, $b_1$, $a_2$ y $b_2$, para la región $R=\left[a_1,b_1\right]\times\left[a_2,b_2\right]$ y grafíque esta región.

# %% [markdown]
# ---
# ## Fractal aleatorio tipo Barnsley
#
# - En la clase de fractales aleatorios vimos que el fractal helecho de Barnsley se generaba a través de cuatro transformaciones afines que se elegían con cierta probabilidad.
# - Vimos que este helecho representaba de manera muy aproximada helechos reales.
# - Vimos que modificando parámetros de la tabla, se podían generar mutaciones de el helecho.
#
# Pues bien, usando la misma idea de transformaciones afines que se escogen con cierta probabilidad, se pueden generar una infinidad inimaginable de fractales. Incluso, se pueden generar fractales aleatorios que poseen un atractor determinístico.
#
# **Referencia:**
# - Barnsley, Michael F. *Fractals Everywhere: New Edition*, ISBN: 9780486320342.

# %% [markdown]
# Usando la siguiente tabla, evalúe el fractal de Barnsley para 100 000 puntos.

# %%
import pandas as pd
import numpy as np

# %%
i = np.arange(4)

df = pd.DataFrame(index=i,columns=['$a_i$', '$b_i$', '$c_i$', '$d_i$', '$e_i$', '$f_i$', '$p_i$'], dtype='float')
df.index.name = "$i$"

df['$a_i$'] = [0.5, 0.5, 0.5, 0.5]
df['$b_i$'] = [0.0, 0.0, 0.0, 0.0]
df['$c_i$'] = [0.0, 0.0, 0.0, 0.0]
df['$d_i$'] = [0.5, 0.5, 0.5, 0.5]
df['$e_i$'] = [1.0, 50.0, 1.0, 50.0]
df['$f_i$'] = [1.0, 1.0, 50.0, 50.0]
df['$p_i$'] = [0.1, 0.2, 0.3, 0.4]

df.round(2)
# Out:
#      $a_i$  $b_i$  $c_i$  $d_i$  $e_i$  $f_i$  $p_i$
# $i$
# 0      0.5    0.0    0.0    0.5    1.0    1.0    0.1
# 1      0.5    0.0    0.0    0.5   50.0    1.0    0.2
# 2      0.5    0.0    0.0    0.5    1.0   50.0    0.3
# 3      0.5    0.0    0.0    0.5   50.0   50.0    0.4

# %%
import random 
x=[0]
y=[0]
for k in range(100000):
    i=random.choices([0,1,2,3],weights=df["$p_i$"])
    
    a=float(df["$a_i$"][i])
    b=float(df["$b_i$"][i])
    c=float(df["$c_i$"][i])
    d=float(df["$d_i$"][i])
    e=float(df["$e_i$"][i])
    f=float(df["$f_i$"][i])
    
    xkm1 = a*x[-1]+b*y[-1]+e
    ykm1 = c*x[-1]+d*y[-1]+f
    x.append(xkm1)
    y.append(ykm1)

# %%
plt.figure(figsize=(7,10))
plt.scatter(x,y,s=1,c="g")

# %% [markdown]
# ---
# ## Probabilidad Precio-Umbral
#
# En las últimas clases vimos una aplicación de simulación montecarlo. Consistía en descargar datos históricos de precio de cierre de acciones de alguna compañía, proyectar esos precios y sacar la probabilidad de que los precios en el siguiente año sobrepasaran cierto precio umbral.
#
# En este ejemplo evaluaremos dos compañías con tendencias más o menos similares (Apple y Microsoft) veremos cuál tiene más probabilidades de darnos un interés deseado.
#
# Además, descargaremos los datos del año 2020 para ver si el análisis concuerda.

# %% [markdown]
# Descargue datos para Apple y Microsoft desde enero de 2015 a diciembre de 2019 y muestre sus gráficas.

# %%
import yfinance as yf

# %%
def getClose(name, start, end) :
    return yf.download(name,start,end)["Adj Close"]

# %%
data = getClose(["AAPL", "MSFT"], "2015-01-01", "2019-12-31")
data
# Out:
# [*********************100%%**********************]  2 of 2 completed
#                  AAPL        MSFT
# Date
# 2015-01-02  24.498680   40.534843
# 2015-01-05  23.808519   40.162094
# 2015-01-06  23.810755   39.572617
# 2015-01-07  24.144642   40.075413
# 2015-01-08  25.072329   41.254349
# ...               ...         ...
# 2019-12-23  69.261597  151.994141
# 2019-12-24  69.327446  151.965179
# 2019-12-26  70.702934  153.210754
# 2019-12-27  70.676102  153.490768
# 2019-12-30  71.095566  152.167938
#
# [1257 rows x 2 columns]

# %% [markdown]
# Calcule los rendimientos diarios junto con sus características estadísticas

# %%
R = (data - data.shift())/data.shift()
R.plot.hist(alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 2023-11-30  0.003787 -0.000138 -0.019050  0.014777  0.020415  0.010276
# 2023-12-01  0.000718  0.000954 -0.016560  0.000755  0.021307  0.019738
# 2023-12-02  0.008499 -0.004548  0.011991  0.031377  0.023820 -0.001593
# 2023-12-03 -0.012094  0.023072 -0.004796  0.010195 -0.012205 -0.012935
# 2023-12-04 -0.015639  0.044412 -0.026487 -0.000139 -0.004509  0.005525
#
#                  998       999
# 2023-10-16  0.001925  0.009183
# 2023-10-17 -0.003407  0.049870
# 2023-10-18 -0.004044  0.008632
# 2023-10-19  0.024930  0.004082
# 2023-10-20 -0.002274  0.005063
# 2023-10-21  0.002992  0.003821
# 2023-10-22  0.008817  0.005085
# 2023-10-23  0.011157  0.001610
# 2023-10-24 -0.010790  0.004273
# 2023-10-25 -0.009788 -0.001006
# 2023-10-26 -0.011600 -0.006540
# 2023-10-27  0.006944 -0.004918
# 2023-10-28  0.018358 -0.004047
# 2023-10-29 -0.002623  0.006749
# 2023-10-30  0.015073 -0.005079
# 2023-10-31  0.005172  0.016731
# 2023-11-01 -0.001171 -0.000105
# 2023-11-02 -0.011905  0.000419
# 2023-11-03  0.010353  0.011204
# 2023-11-04  0.017591  0.011016
# 2023-11-05 -0.012097  0.009644
# 2023-11-06  0.003023 -0.033495
# 2023-11-07  0.017175  0.001787
# 2023-11-08 -0.004488 -0.005282
# 2023-11-09 -0.003687 -0.017515
# 2023-11-10 -0.017080  0.015846
# 2023-11-11 -0.014461 -0.021553
# 2023-11-12 -0.026556 -0.035032
# 2023-11-13 -0.009533 -0.019042
# 2023-11-14  0.006774  0.018275
# 2023-11-15 -0.019020  0.015661
# 2023-11-16  0.027261  0.019187
# 2023-11-17 -0.010899 -0.018999
# 2023-11-18  0.020315  0.025976
# 2023-11-19 -0.019209  0.004354
# 2023-11-20 -0.002893 -0.011112
# 2023-11-21  0.013366 -0.000402
# 2023-11-22  0.003377  0.029548
# 2023-11-23 -0.014223  0.007781
# 2023-11-24  0.022435  0.029210
# 2023-11-25  0.027101 -0.006353
# 2023-11-26 -0.005810  0.008356
# 2023-11-27 -0.014952  0.011669
# 2023-11-28 -0.012542  0.003954
# 2023-11-29 -0.016464  0.013479
# 2023-11-30  0.014889  0.007738
# 2023-12-01 -0.009228  0.007253
# 2023-12-02  0.002133 -0.007018
# 2023-12-03 -0.013019 -0.011565
# 2023-12-04  0.016036  0.024952
#
# [50 rows x 1000 columns]

# %% [markdown]
# Calcule los precios con base en los rendimientos simulados

# %%
valor_deseado=data[-1]*1.03
data[-1],valor_deseado
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 valor_deseado=data[-1]*1.03
#       2 data[-1],valor_deseado
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: -1

# %% [markdown]
# Calcule la probabilidad de obtener un retorno del 20% para ambas marcas.

# %% [markdown]
# Finalmente, grafique los datos reales del 2020 para ver que tan acertado fue nuestro análisis.

# %% [markdown]
# ## Probabilidad

# %% [markdown]
# Imagina que en un país la estatura promedio es 164 centímetros, con una desviación estándar de 4 centímetros. ¿Cuál es la probabilidad de que si sumamos la estatura de 20 personas se obtenga un valor mayor a 30 metros?
